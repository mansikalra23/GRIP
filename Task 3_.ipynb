# %% [markdown]
# # MANSI KALRA

# %% [markdown]
# # Task #3 : Prediction using Decision Tree Algorithm

# %% [markdown]
# _**Objective :** Creating the Decision Tree classifier of the given ‘Iris’ dataset, and visualizing it graphically._

# %%
# Load libraries
import pandas as pd
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
# loading the iris dataset and creating dataframe
iris=datasets.load_iris()
df=pd.DataFrame(iris.data, columns=iris.feature_names)
df.head(10)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4
# 6                4.6               3.4                1.4               0.3
# 7                5.0               3.4                1.5               0.2
# 8                4.4               2.9                1.4               0.2
# 9                4.9               3.1                1.5               0.1

# %%
#split dataset in features and target variable
X = df[iris.feature_names] # Features
y = iris.target # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
from sklearn import tree

# Create Decision Tree classifer object
clf = tree.DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9555555555555556

# %%
# !pip install PyHamcrest>=1.9.0
# !pip install pydotplus
# !pip install graphviz
# Out:
# You are using pip version 10.0.1, however version 20.2.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# ...
# You are using pip version 10.0.1, however version 20.2.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# ...
#   Using cached https://files.pythonhosted.org/packages/1f/15/829918d2078de497d9905cb620be4e17caa75829d741a7c1649257316ea5/graphviz-0.14.2-py2.py3-none-any.whl
# ...
# You are using pip version 10.0.1, however version 20.2.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus
import graphviz
import os
path_graphviz = r"E:\New folder\anaconda\pkgs\Graphviz 2.44.1\bin" # replace by your Graphviz bin path
os.environ["PATH"] += os.pathsep + path_graphviz

    
dot_data = StringIO()
export_graphviz(clf, out_file=dot_data, feature_names=iris.feature_names,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
